# %%
import pandas as pd
import os

# %%
path = r'p:\11208003-latedeo2022\020_InternationalDeltaPortfolio\00_mapping_global_threat_of_land_subsidence'

df1 = pd.read_excel(os.path.join(path, 'abb8549_data_s1.xlsx')).dropna(subset = 'Reference')
                    
df1
# Out:
#                    Name        Country  Area (km2)  WGS84 latitude (degrees)  \
# 0                Chiayi         Taiwan       340.0                120.213276
# 1    Acque Albule Basin          Italy         NaN                 12.732554
# 2        Aguascalientes         Mexico        83.0               -102.290222
# 3            Ahuacatlan         Mexico         5.0               -104.489734
# 4               Alamosa  United States       127.0               -105.962837
# ..                  ...            ...         ...                       ...
# 196     Xuchang-Zhoukou          China         NaN                114.249460
# 197              Yangon        Myanmar         NaN                 96.219570
# 198               Yilan         Taiwan       142.0                121.802806
# 199              Yunlin         Taiwan       853.0                120.291439
# 200              Zamora         Mexico        16.0               -102.280838
#
#      WGS84 longitude (degrees) Reference
# ...

# %%
df2 = pd.read_excel(os.path.join(path, 'abb8549_data_s3.xlsx')).columns
                    
df2
# Out:
# Index(['Country', 'Number of subsidene events (NSE)', 'Normalized NSE',
#        'Potential subsidence extent in 2010 (SHE) (1000 km2)',
#        'Potential exposed population in 2010 (Million)',
#        'Potential exposed population in non-floodable areas in 2010 (EPNF) (Million)',
#        'Potenital exposed population in river floodable areas in 2010 (EPRF) (Million)',
#        'Potential exposed populaiton in coastal flood areas lower than 5 m a.s.l and above the mean sea level (EPCF) (Million)',
#        'Potential exposed populaiton below the sea level in 2010 (EPBS) (Million)',
#        'Normalized EPNF 2010', 'Normalized EPRF 2010', 'Normalized EPCF 2010',
#        'Normalized EPBS 2010', 'Potential exposed population index (EP 2010)',
#        'Normalized EP 2010',
#        'Population density in potential subsidence (PDS) (inhabitants / km2)',
#        'Normalized PDS in 2010',
# ...
