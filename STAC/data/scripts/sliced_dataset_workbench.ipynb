# %% [markdown]
# # Global Coastal Atlas workbench
#
# In this notebook, we will show how to use the Global Coastal Atlas workbench to access and process data from the Global Coastal Atlas.
# Some functions have been prepared to quickly get data from the area of interest marked on the website.

# %% [markdown]
# ## Install requirements
# First, we need to install the requirements. This can take a few minutes.

# %%
# %pip install shapely xarray rioxarray
# Out:
# Requirement already satisfied: shapely in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: xarray in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (2023.9.0)
# Requirement already satisfied: rioxarray in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (0.15.0)
# Requirement already satisfied: numpy>=1.14 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from shapely) (1.26.0)
# Requirement already satisfied: packaging>=21.3 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from xarray) (23.2)
# Requirement already satisfied: pandas>=1.4 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from xarray) (2.1.1)
# Requirement already satisfied: rasterio>=1.2 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rioxarray) (1.3.8)
# Requirement already satisfied: pyproj>=2.2 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rioxarray) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from pandas>=1.4->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from pandas>=1.4->xarray) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from pandas>=1.4->xarray) (2023.3)
# Requirement already satisfied: certifi in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from pyproj>=2.2->rioxarray) (2023.7.22)
# Requirement already satisfied: affine in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (23.1.0)
# Requirement already satisfied: click>=4.0 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (1.4.7)
# Requirement already satisfied: click-plugins in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (1.1.1)
# Requirement already satisfied: setuptools in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from rasterio>=1.2->rioxarray) (68.2.2)
# Requirement already satisfied: six>=1.5 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.4->xarray) (1.16.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/nathan/micromamba/envs/globalcoastalatlas/lib/python3.10/site-packages (from snuggs>=1.4.1->rasterio>=1.2->rioxarray) (3.1.1)
# DEPRECATION: mapbox 0.16.1 has a non-standard dependency specifier python-dateutil>=2.5.0requests. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of mapbox or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# DEPRECATION: nb-black 1.0.7 has a non-standard dependency specifier black>='19.3'; python_version >= "3.6". pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of nb-black or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Note: you may need to restart the kernel to use updated packages.

# %%
# Define input

geojson_str = """
{
    "coordinates": [
        [
        [
            90.89270322181983,
            24.89144849850402
        ],
        [
            87.51739497682678,
            23.95385040469374
        ],
        [
            87.23135190521862,
            20.297974055822536
        ],
        [
            93.35267363766218,
            19.544987025644943
        ],
        [
            95.01172345299642,
            23.219849978261337
        ],
        [
            90.89270322181983,
            24.89144849850402
        ]
        ]
    ],
    "type": "Polygon"
    }
"""

zarr_urls = {
    "esl_gwl": "https://storage.googleapis.com/dgds-data-public/gca/ESLbyGWL.zarr",
    "sub_threat": "https://storage.googleapis.com/dgds-data-public/gca/Global_TLS.zarr",
    "waves_by_cowclip": "./../temp/waves_by_cowclip_cf_merged.zarr"
    
}

# %% [markdown]
# ## Define functions
# A class is defined that can be used for fetching and slicing a remote zarr.

# %%
from enum import Enum
import shapely
import xarray as xr
import numpy as np

class DatasetType(Enum):
    RASTER = "raster"
    POINT = "point"
    

class ZarrSlicer:

    @staticmethod
    def get_sliced_dataset(geojson_str: str, zarr_uri: str) -> xr.Dataset:
        """Fetch Zarr from remote store and slice with geojson polygon

        Args:
            geojson_str (str): String containing geojson polygon
            zarr_uri (str): String containing zarr uri

        Returns:
            xr.Dataset: sliced lazy loaded zarr dataset
        """
        polygon_shape = ZarrSlicer._create_shape_from_geojson(geojson_str)
        zarr = ZarrSlicer._get_dataset_from_zarr_url(zarr_uri)
        sliced_zarr = ZarrSlicer.slice_xarr_with_polygon(zarr, polygon_shape)
        return sliced_zarr

    @staticmethod
    def slice_xarr_with_polygon(
        xarr: xr.Dataset, polygon: shapely.Polygon
    ) -> xr.Dataset:
        """Slice xarray dataset with geojson polygon

        Args:
            xarr (xr.Dataset): xarray dataset
            polygon (Polygon): geojson polygon

        Returns:
            xr.Dataset: sliced xarray dataset
        """
        dataset_type = ZarrSlicer._get_dataset_type(xarr)

        if dataset_type == DatasetType.RASTER:
            spatial_dims = ZarrSlicer._get_spatial_dimensions(xarr)
            indexer = ZarrSlicer._get_indexer_from_raster(xarr, polygon, spatial_dims)
        elif dataset_type == DatasetType.POINT:
            points = ZarrSlicer._create_points_from_xarr(xarr)
            boolean_mask = ZarrSlicer._get_boolean_mask_from_points(points, polygon)
            spatial_dims = ZarrSlicer._get_spatial_dimensions(xarr)

            indexer = {spatial_dims[0]: boolean_mask}
        else:
            raise ValueError("Dataset type not supported")    
        
        sliced_xarr = xarr.sel(indexer)
        return sliced_xarr

    @staticmethod
    def _get_dataset_type(xarr: xr.Dataset) -> str:
        """Get dataset type from xarray dataset. We differentiate between
        raster and point datasets"""
        # if lat and lon are dimensions, we assume it is a raster dataset
        if "lat" in xarr.dims and "lon" in xarr.dims:
            return DatasetType.RASTER
        else:
            return DatasetType.POINT

    @staticmethod
    def _create_points_from_xarr(xarr: xr.Dataset) -> shapely.MultiPoint:
        """Create shapely multipoint from xarray dataset"""
        lats = xarr.coords["lat"].values
        lons = xarr.coords["lon"].values
        points = shapely.points(lons, lats)
        return points

    @staticmethod
    def _get_spatial_dimensions(xarr: xr.Dataset) -> list[str]:
        """Get spatial dimension from xarray dataset"""
        dims = {xarr.lat.dims[0], xarr.lon.dims[0]}
        return list(dims)

    @staticmethod
    def _get_boolean_mask_from_points(
        points: shapely.MultiPoint, polygon: shapely.Polygon
    ) -> [bool]:
        """Get boolean mask from points and polygon"""
        return shapely.within(points, polygon)

    @staticmethod
    def _get_indexer_from_raster(
        raster: xr.Dataset, polygon: shapely.Polygon,
        spatial_dims: list[str]
    ) -> [bool]:
        """Get boolean mask from raster and polygon"""
        spatial_dim_size = { dim: len(raster[dim].values) for dim in spatial_dims }

        coords = np.stack(np.meshgrid(
                            raster[spatial_dims[1]].values, raster[spatial_dims[0]].values
                            ),
                        -1).reshape(
                                spatial_dim_size[spatial_dims[0]], 
                                spatial_dim_size[spatial_dims[1]], 2)

        raster_points = shapely.points(coords)

        mask = shapely.within(raster_points, polygon_shape)

        # Reduce mask to square shape
        # TODO: create point wise indexing for DataSet; 
        indexer = {
            'lat': mask.any(axis=1),
            'lon': mask.any(axis=0)
        }
        return indexer
    
    @staticmethod
    def _create_shape_from_geojson(geojson: str) -> shapely.Polygon:
        """Create shapely polygon from geojson polygon"""
        return shapely.from_geojson(geojson)

    @staticmethod
    def _get_dataset_from_zarr_url(url: str) -> xr.Dataset:
        """Get zarr store from url"""
        return xr.open_zarr(url)


zarrs = []
for zarr_uri in zarr_urls:

    polygon_shape = ZarrSlicer._create_shape_from_geojson(geojson_str)
    zarr = ZarrSlicer._get_dataset_from_zarr_url(zarr_uri)
    zarrs.append(zarr)

    sliced_xarr = ZarrSlicer.get_sliced_dataset(geojson_str, zarr_uri=zarr_uri)

    print(f"zarr size: {zarr.nbytes / 1e9} GB")

    print(f"sliced zarr size: {sliced_xarr.nbytes / 1e9} GB")
# Out:
# zarr size: 0.000117614 GB
# sliced zarr size: 2.1035e-05 GB
# zarr size: 0.118359908 GB
# sliced zarr size: 0.001095933 GB
# zarr size: 0.125456964 GB
# sliced zarr size: 6.7324e-05 GB
