# %% [markdown]
# # World_Pop Population 100m
#
# Notebook environment to migrate csv files to CF compliant zarr

# %%
# Optional; code formatter, installed as jupyter lab extension
#%load_ext lab_black
# Optional; code formatter, installed as jupyter notebook extension
# %load_ext nb_black

# %%
# Import standard packages
import os
import pathlib
import sys

import numpy as np
#import geopandas as gpd
 
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import glob
import itertools
import json
import copy
from itertools import chain
from shapely import wkb

import dask.dataframe as dd
import tqdm
from tqdm import tqdm


# Import custom functionality
# sys.path.append('c:/Windows/System32/coclicodata/src')#CLENMAR ADDED

from coclicodata.drive_config import p_drive
from coclicodata.etl.cf_compliancy_checker import check_compliancy, save_compliancy

# Define (local and) remote drives
gca_data_dir = r"P:\11209197-018-global-coastal-atlas\MSc_students\ClenmarRowe\Data\All_Datasets\Orig_Datasets\02_Exposure"
#gca_data_dir = p_drive.joinpath("11209197-018-global-coastal-atlas","MSc_students","ClenmarRowe")

# Workaround to the Windows OS (10) udunits error after installation of cfchecker: https://github.com/SciTools/iris/issues/404
os.environ["UDUNITS2_XML_PATH"] = str(
    pathlib.Path().home().joinpath(  # change to the udunits2.xml file dir in your Python installation
        r"AppData\Local\miniconda3\pkgs\udunits2-2.2.28-h892ecd3_0\Library\share\udunits\udunits2.xml" ###Changed from anaconda to miniconda  - added the new package udunits file
    )
)

# %%
# Project paths & files (manual input)
dataset_dir = pathlib.Path().joinpath(gca_data_dir,"Population","worldpop")
dataset_dir_path = dataset_dir.joinpath("World_Pop_100m_original.nc")
CF_dir = dataset_dir.joinpath("CF")  # directory to save output CF check files
CF_dir
# Out:
# WindowsPath('P:/11209197-018-global-coastal-atlas/MSc_students/ClenmarRowe/Data/All_Datasets/Orig_Datasets/02_Exposure/Population/worldpop/CF')

# %%
filename=dataset_dir.joinpath("World_Pop_2020_100m_UNadj_centroid_final.csv")
df_orig= dd.read_csv(filename, header=0)
df_orig.head()
# Out:
#    fid  pop_count                            layer          area  perimeter  \
# 0    1          0  _abw_ppp_2020_UNadj_constrained  1.388889e-06   0.005000
# 1    2          0  _abw_ppp_2020_UNadj_constrained  1.388889e-06   0.005000
# 2    3          2  _abw_ppp_2020_UNadj_constrained  2.083333e-06   0.006667
# 3    4          4  _abw_ppp_2020_UNadj_constrained  6.944444e-07   0.003333
# 4    5          0  _abw_ppp_2020_UNadj_constrained  1.388889e-06   0.005000
#
#    Tot_pop_count     xcoord     ycoord
# 0              0 -70.053750  12.615833
# 1              0 -70.053750  12.614167
# 2              6 -70.053055  12.607222
# 3              4 -70.047500  12.606667
# 4              0 -70.046250  12.606667

# %%
df=df_orig.drop(["pop_count","layer","area","perimeter","Tot_pop_count"], axis=1)

df["Tot_pop_count"]=df_orig["Tot_pop_count"]
df=df.rename({"xcoord":"lon", "ycoord":"lat"})
df=df.drop(["fid"], axis=1)
df
# Out:
# Dask DataFrame Structure:
#                   xcoord   ycoord Tot_pop_count
# npartitions=339
#                  float64  float64         int64
#                      ...      ...           ...
# ...                  ...      ...           ...
#                      ...      ...           ...
#                      ...      ...           ...
# Dask Name: assign, 5 graph layers

# %%
df.npartitions
# Out:
# 339

# %%
# # save each dask dataset partition as a different netcdf file

# for part in tqdm(range(df.npartitions),desc="parts completed"):
    
#     df_part=df.partitions[part]
    
#     if part>0:
#         df_part_prev= df.partitions[part-1]
#         prev_max= df_part_prev["index"].values.max
#         df_part["index"]= df_part["index"].values + prev_max


#     ds = xr.Dataset.from_dataframe( df_part)
#     ds.to_netcdf(str(dataset_dir.joinpath("netcdf_parts","World_Pop_100m"+str(part)+".nc")))
# ds
# Out:
# parts completed: 100%|██████████| 339/339 [37:38<00:00,  6.66s/it]

# %% [markdown]
# ### Check CF compliancy original NetCDF files

# %%
# %%capture cap --no-stderr
# check original CF compliancy (for first file)

check_compliancy(testfile=dataset_dir.joinpath("netcdf_parts","World_Pop_100m"+str(part)+".nc"), 
                 working_dir=CF_dir
                 )

# %%
# save original CF compliancy (for first file)
save_compliancy(cap, testfile=dataset_dir_path, working_dir=CF_dir)
# Out:
# {'P:\\11209197-018-global-coastal-atlas\\MSc_students\\ClenmarRowe\\Data\\All_Datasets\\Orig_Datasets\\02_Exposure\\Population\\worldpop\\netcdf_parts\\World_Pop_100m338.nc': {'warnings': '6', 'errors': '0'}}

# %% [markdown]
# ### Make CF compliant alterations to the NetCDF files (dataset dependent)

# %%
# Get a list of all netCDF files in the specified directory
files = sorted(glob.glob(os.path.join(dataset_dir ,"netcdf_parts",  "*.nc")))

# Open datasets using lazily in Chunks
datasets = [xr.open_dataset(f, chunks={'index':  10000}) for f in files]
datasets
# Out:
# [<xarray.Dataset>
#  Dimensions:        (index: 528878)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 528874 528875 528876 528877
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 531421)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 531417 531418 531419 531420
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 531835)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 531831 531832 531833 531834
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524695)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524691 524692 524693 524694
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524390)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524386 524387 524388 524389
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525661)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525657 525658 525659 525660
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526315)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526311 526312 526313 526314
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 528542)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 528538 528539 528540 528541
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 528027)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 528023 528024 528025 528026
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525946)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525942 525943 525944 525945
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525120)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525116 525117 525118 525119
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526425)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526421 526422 526423 526424
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526445)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526441 526442 526443 526444
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 527630)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 527626 527627 527628 527629
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524401)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524397 524398 524399 524400
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524620)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524616 524617 524618 524619
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525251)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525247 525248 525249 525250
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524949)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524945 524946 524947 524948
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523081)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523077 523078 523079 523080
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520048)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520044 520045 520046 520047
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519931)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519927 519928 519929 519930
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519605)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519601 519602 519603 519604
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517483)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517479 517480 517481 517482
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520273)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520269 520270 520271 520272
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526953)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526949 526950 526951 526952
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517662)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517658 517659 517660 517661
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 516935)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 516931 516932 516933 516934
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520853)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520849 520850 520851 520852
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523690)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523686 523687 523688 523689
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526634)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526630 526631 526632 526633
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523097)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523093 523094 523095 523096
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517235)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517231 517232 517233 517234
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 516897)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 516893 516894 516895 516896
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 515417)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 515413 515414 515415 515416
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 516238)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 516234 516235 516236 516237
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 527182)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 527178 527179 527180 527181
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517248)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517244 517245 517246 517247
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 518278)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 518274 518275 518276 518277
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523553)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523549 523550 523551 523552
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524352)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524348 524349 524350 524351
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523322)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523318 523319 523320 523321
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520285)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520281 520282 520283 520284
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523429)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523425 523426 523427 523428
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522911)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522907 522908 522909 522910
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522957)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522953 522954 522955 522956
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524644)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524640 524641 524642 524643
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525796)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525792 525793 525794 525795
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522276)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522272 522273 522274 522275
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522305)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522301 522302 522303 522304
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522006)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522002 522003 522004 522005
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522055)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522051 522052 522053 522054
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521531)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521527 521528 521529 521530
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521208)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521204 521205 521206 521207
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521967)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521963 521964 521965 521966
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522380)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522376 522377 522378 522379
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524843)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524839 524840 524841 524842
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523088)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523084 523085 523086 523087
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524440)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524436 524437 524438 524439
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523205)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523201 523202 523203 523204
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522904)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522900 522901 522902 522903
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521958)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521954 521955 521956 521957
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522872)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522868 522869 522870 522871
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523534)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523530 523531 523532 523533
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 527374)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 527370 527371 527372 527373
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523254)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523250 523251 523252 523253
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522851)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522847 522848 522849 522850
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520994)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520990 520991 520992 520993
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522992)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522988 522989 522990 522991
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524386)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524382 524383 524384 524385
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522050)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522046 522047 522048 522049
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521173)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521169 521170 521171 521172
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522556)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522552 522553 522554 522555
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522650)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522646 522647 522648 522649
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522287)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522283 522284 522285 522286
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521898)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521894 521895 521896 521897
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522595)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522591 522592 522593 522594
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524746)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524742 524743 524744 524745
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522943)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522939 522940 522941 522942
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521635)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521631 521632 521633 521634
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524298)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524294 524295 524296 524297
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521203)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521199 521200 521201 521202
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525206)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525202 525203 525204 525205
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525680)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525676 525677 525678 525679
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525919)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525915 525916 525917 525918
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525459)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525455 525456 525457 525458
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523791)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523787 523788 523789 523790
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525531)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525527 525528 525529 525530
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525407)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525403 525404 525405 525406
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522116)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522112 522113 522114 522115
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523766)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523762 523763 523764 523765
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525154)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525150 525151 525152 525153
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523426)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523422 523423 523424 523425
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524447)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524443 524444 524445 524446
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524365)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524361 524362 524363 524364
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524238)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524234 524235 524236 524237
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522554)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522550 522551 522552 522553
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 518391)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 518387 518388 518389 518390
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519028)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519024 519025 519026 519027
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 518939)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 518935 518936 518937 518938
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521569)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521565 521566 521567 521568
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524005)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524001 524002 524003 524004
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 512630)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 512626 512627 512628 512629
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522175)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522171 522172 522173 522174
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 518273)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 518269 518270 518271 518272
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519018)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519014 519015 519016 519017
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519975)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519971 519972 519973 519974
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517638)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517634 517635 517636 517637
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 515562)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 515558 515559 515560 515561
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517911)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517907 517908 517909 517910
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517985)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517981 517982 517983 517984
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517135)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517131 517132 517133 517134
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 514585)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 514581 514582 514583 514584
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 528639)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 528635 528636 528637 528638
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 513030)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 513026 513027 513028 513029
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 512835)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 512831 512832 512833 512834
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 513172)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 513168 513169 513170 513171
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519748)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519744 519745 519746 519747
#  Data variables:
# ...
#    * index          (index) int64 0 1 2 3 4 ... 523537 523538 523539 523540
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522936)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522932 522933 522934 522935
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522701)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522697 522698 522699 522700
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522188)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522184 522185 522186 522187
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521512)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521508 521509 521510 521511
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521685)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521681 521682 521683 521684
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 528674)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 528670 528671 528672 528673
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522379)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522375 522376 522377 522378
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521996)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521992 521993 521994 521995
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521480)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521476 521477 521478 521479
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524037)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524033 524034 524035 524036
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525745)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525741 525742 525743 525744
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526076)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526072 526073 526074 526075
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521061)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521057 521058 521059 521060
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 518909)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 518905 518906 518907 518908
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520091)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520087 520088 520089 520090
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519055)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519051 519052 519053 519054
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525722)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525718 525719 525720 525721
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 517414)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 517410 517411 517412 517413
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 516746)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 516742 516743 516744 516745
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526350)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526346 526347 526348 526349
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526811)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526807 526808 526809 526810
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525764)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525760 525761 525762 525763
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526253)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526249 526250 526251 526252
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526110)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526106 526107 526108 526109
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 523332)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 523328 523329 523330 523331
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 520901)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 520897 520898 520899 520900
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 516334)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 516330 516331 516332 516333
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 528753)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 528749 528750 528751 528752
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 521307)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 521303 521304 521305 521306
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 524050)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 524046 524047 524048 524049
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522639)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522635 522636 522637 522638
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 519720)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 519716 519717 519718 519719
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 522555)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 522551 522552 522553 522554
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 527686)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 527682 527683 527684 527685
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525911)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525907 525908 525909 525910
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526837)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526833 526834 526835 526836
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 526073)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 526069 526070 526071 526072
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>,
#  <xarray.Dataset>
#  Dimensions:        (index: 525703)
#  Coordinates:
#    * index          (index) int64 0 1 2 3 4 ... 525699 525700 525701 525702
#  Data variables:
#      xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#      Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>]

# %%
datasets[0]
# Out:
# <xarray.Dataset>
# Dimensions:        (index: 528878)
# Coordinates:
#   * index          (index) int64 0 1 2 3 4 ... 528874 528875 528876 528877
# Data variables:
#     xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>

# %%
datasets2=[]
for part in tqdm(range(df.npartitions),desc="parts completed"):
    
    ds_part=datasets[part]
    
    if part>0:
        ds_part_prev= datasets[part-1]
        prev_max= ds_part_prev["index"].values.max()
        ds_part["index"]= ds_part["index"].values + prev_max +1

    datasets2.append(ds_part)
# Out:
# parts completed: 100%|██████████| 339/339 [00:02<00:00, 129.24it/s]

# %%
datasets[2]
# Out:
# <xarray.Dataset>
# Dimensions:        (index: 531835)
# Coordinates:
#   * index          (index) int64 1060299 1060300 1060301 ... 1592132 1592133
# Data variables:
#     xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>

# %%
datasets2[2]
# Out:
# <xarray.Dataset>
# Dimensions:        (index: 531835)
# Coordinates:
#   * index          (index) int64 1060299 1060300 1060301 ... 1592132 1592133
# Data variables:
#     xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>

# %%
# Concatenate the datasets along the index dimension
ds = xr.concat(datasets2, dim='index')#.compute()

# Save the merged dataset to a new netCDF file in the current directory

ds
# Out:
# <xarray.Dataset>
# Dimensions:        (index: 179243956)
# Coordinates:
#   * index          (index) int64 0 1 2 3 ... 179243953 179243954 179243955
# Data variables:
#     xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>

# %%
import json

# NetCDF attribute alterations by means of metadata template
metadata_json=dataset_dir.joinpath("World_Pop_100m_metadata.json")

f_global = open(metadata_json)
meta_global = json.load(f_global)


for attr_name, attr_val in meta_global.items():
    if attr_name == 'PROVIDERS':
        attr_val = json.dumps(attr_val)
    ds.attrs[attr_name] = attr_val

ds.attrs['Conventions'] = "CF-1.8"
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (index: 179243956)
# Coordinates:
#   * index          (index) int64 0 1 2 3 ... 179243953 179243954 179243955
# Data variables:
#     xcoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     ycoord         (index) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     Tot_pop_count  (index) int64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Attributes: (12/21)
#     TITLE:               World Pop
#     TITLE_ABBREVIATION:  WP
#     DESCRIPTION:         Consits of a 100m resolution a global population dis...
#     SHORT_DESCRIPTION:   100m High-resolution global population distribution ...
#     INSTITUTION:         University of Southampton
#     PROVIDERS:           {"name": "University of Southampton", "url": "https:...
#     ...                  ...
#     DOI:                 https://doi.org/10.5258/SOTON/WP00685
#     LONG_NAME:           WORLD_POPULATION_DISTRIBUTION
#     UNITS:               individuals
#     COMMENT:             The dataset includes constrained, UN adjusted global...
#     CRS:                 EPSG:4326
#     Conventions:         CF-1.8

# %%
ds = ds.rename_dims({"index": "nstations"})

# rename variables, if necessary
ds = ds.rename_vars(
        {"xcoord": "lon", "ycoord": "lat","index":"stations"} #"index":"nstations", 
  )

# ds=ds.drop(["index"])
# set some data variables to coordinates to avoid duplication of dimensions in later stage

ds = ds.set_coords(["lon", "lat"])
# for var in ds.variables:
#     ds = ds.set_coords(var)

ds
# Out:
# <xarray.Dataset>
# Dimensions:        (nstations: 179243956)
# Coordinates:
#   * stations       (nstations) int64 0 1 2 3 ... 179243953 179243954 179243955
#     lon            (nstations) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     lat            (nstations) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Dimensions without coordinates: nstations
# Data variables:
#     Tot_pop_count  (nstations) int64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Attributes: (12/21)
#     TITLE:               World Pop
#     TITLE_ABBREVIATION:  WP
#     DESCRIPTION:         Consits of a 100m resolution a global population dis...
#     SHORT_DESCRIPTION:   100m High-resolution global population distribution ...
#     INSTITUTION:         University of Southampton
#     PROVIDERS:           {"name": "University of Southampton", "url": "https:...
#     ...                  ...
#     DOI:                 https://doi.org/10.5258/SOTON/WP00685
#     LONG_NAME:           WORLD_POPULATION_DISTRIBUTION
#     UNITS:               individuals
#     COMMENT:             The dataset includes constrained, UN adjusted global...
#     CRS:                 EPSG:4326
#     Conventions:         CF-1.8

# %%
# add or change certain variable / coordinate attributes
### dataset attributes is a dictionary of dictionaries
dataset_attributes = {
#    "Scenario": {"long_name": "RCP Scenario", "units": "1"}, # set to 1 if no unit
#    "Time_Horizon": {"long_name": "time", "units": "yr"}, # set to 1 if no unit
    "lon": {"standard_name": "longitude", "long_name": "longitude", "units": "degrees_east"},
    "lat": {"standard_name": "latitude", "long_name": "latitude", "units": "degrees_north"},
    "stations": {"long_name": "stations", "units": "1"}, # set to 1 if no unit
    "Tot_pop_count": { "long_name": "Population count UN Adjusted Constrained", "units": "1"},
}  # specify custom (CF convention) attributes

 # add / overwrite attributes
for k, v in dataset_attributes.items():
    try:
        ds[k].attrs = dataset_attributes[k]
    except:
        continue
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (nstations: 179243956)
# Coordinates:
#   * stations       (nstations) int64 0 1 2 3 ... 179243953 179243954 179243955
#     lon            (nstations) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     lat            (nstations) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Dimensions without coordinates: nstations
# Data variables:
#     Tot_pop_count  (nstations) int64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Attributes: (12/21)
#     TITLE:               World Pop
#     TITLE_ABBREVIATION:  WP
#     DESCRIPTION:         Consits of a 100m resolution a global population dis...
#     SHORT_DESCRIPTION:   100m High-resolution global population distribution ...
#     INSTITUTION:         University of Southampton
#     PROVIDERS:           {"name": "University of Southampton", "url": "https:...
#     ...                  ...
#     DOI:                 https://doi.org/10.5258/SOTON/WP00685
#     LONG_NAME:           WORLD_POPULATION_DISTRIBUTION
#     UNITS:               individuals
#     COMMENT:             The dataset includes constrained, UN adjusted global...
#     CRS:                 EPSG:4326
#     Conventions:         CF-1.8

# %%
# Write the xarray dataset to a netCDF file
#Compliant netcdf
dataset_dir_path_CF=str(dataset_dir_path).replace("original","final")

# %%
ds.to_netcdf(path=dataset_dir_path_CF)

# %% [markdown]
# ### Check CF compliancy modified NetCDF files

# %%
# open datasets (only first file, rest is the same)
ds = xr.open_dataset(dataset_dir_path_CF,chunks={'nstations':  10000})

# check original dataset
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (nstations: 179243956)
# Coordinates:
#     stations       (nstations) int64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     lon            (nstations) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
#     lat            (nstations) float64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Dimensions without coordinates: nstations
# Data variables:
#     Tot_pop_count  (nstations) int64 dask.array<chunksize=(10000,), meta=np.ndarray>
# Attributes: (12/21)
#     TITLE:               World Pop
#     TITLE_ABBREVIATION:  WP
#     DESCRIPTION:         Consits of a 100m resolution a global population dis...
#     SHORT_DESCRIPTION:   100m High-resolution global population distribution ...
#     INSTITUTION:         University of Southampton
#     PROVIDERS:           {"name": "University of Southampton", "url": "https:...
#     ...                  ...
#     DOI:                 https://doi.org/10.5258/SOTON/WP00685
#     LONG_NAME:           WORLD_POPULATION_DISTRIBUTION
#     UNITS:               individuals
#     COMMENT:             The dataset includes constrained, UN adjusted global...
#     CRS:                 EPSG:4326
#     Conventions:         CF-1.8

# %%
# %%capture cap --no-stderr
# check original CF compliancy (for first file)

check_compliancy(testfile=dataset_dir_path_CF, 
                 working_dir=CF_dir
                 )

# %%
# save original CF compliancy (for first file)
save_compliancy(cap, testfile=dataset_dir_path_CF, working_dir=CF_dir)
# Out:
# {'P:\\11209197-018-global-coastal-atlas\\MSc_students\\ClenmarRowe\\Data\\All_Datasets\\Orig_Datasets\\02_Exposure\\Population\\worldpop\\World_Pop_100m_final.nc': {'warnings': '0', 'errors': '0'}}

# %%
from dask.diagnostics import ProgressBar


# # export to zarr in write mode (to overwrite if exists)

with ProgressBar():
    ds.to_zarr(str(dataset_dir_path).replace("original","final").replace(".nc", ".zarr"), mode="w")
# Out:
# [########################################] | 100% Completed | 23m 15s
